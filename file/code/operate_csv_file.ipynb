# %% [markdown]
# # CSV File

# %% [markdown]
# - CSV (Comma-Separated Values，逗號分隔值) 為常見的一種「純文字」資料儲存的檔案格式，將所有資料以半形的逗號隔開，一般的試算表軟體均能處理並儲存CSV格式
# - 健保署的「醫事機構名單」開放資料格式提供的就是CSV檔，可以用Excel開啟  [醫事機構名單](../txt/醫事機構名單.csv)
# - CSV檔可以用一般文字編輯軟體來開啟，例如用記事本開啟，但無法像試算表軟體那樣對齊

# %% [markdown]
# # Import pandas module to read CSV file

# %%
from pathlib import Path
import pandas as pd
file_path = Path.cwd() / '..' / 'csv' / '醫事機構名單.csv'
df = pd.read_csv(file_path)
df.head(5)
# Out:
#       醫醫事機構代碼 事機構名稱 醫事機構種類            電話                       地址  分區業務組 特約類別  \
# 0  5901010058  安郁藥局   藥師自營  (02)25774551   臺北市松山區八德路３段１２巷５１弄１６號１樓  臺北業務組   藥局
# 1  5901010076  榮星藥局  藥劑生自營  (02)27124696     臺北市松山區南京東路４段１３３巷５弄１號  臺北業務組   藥局
# 2  5901010085  安世藥局   藥師自營  (02)27133405     臺北市松山區南京東路４段１３３巷５弄９號  臺北業務組   藥局
# 3  5901010094  明一藥局   藥師自營  (02)27691654  臺北市松山區南京東路５段５９巷２８弄２５號１樓  臺北業務組   藥局
# 4  5901010165  傑安藥局   藥師自營  (02)27524155    臺北市松山區八德路２段４３７巷７弄８號１樓  臺北業務組   藥局
#
#   服務項目 診療科別   終止合約或歇業日期                                             固定看診時段  \
# 0    -    -  20230529.0  星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看...
# 1    -    -  20231129.0  星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看...
# 2    -    -  20230724.0  星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看...
# 3    -    -  20230820.0  星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看...
# 4    -    -  20230215.0  星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看...
#
# ...

# %% [markdown]
# # Lab

# %% [markdown]
# - 請依照下方表格內容, 生成一個檔案，名稱為 city.csv
# - 使用 pandas module 讀取 city.csv, 並且印出前三筆資料
#
# |country|city
# |-------|----
# |Taiwan|Taipei
# |USA|New York
# |Japan|Tokyo
# |UK|London
# |France|Paris
