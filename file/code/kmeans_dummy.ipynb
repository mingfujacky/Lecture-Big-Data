# %% [markdown]
# # k-means by dummy dataset
# randomly generate dataset

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans

data = np.random.rand(100, 2) # 100 points in 2D
plt.scatter(data[:, 0], data[:, 1], color='blue', marker='o', s=30)
plt.show()

# %%
# K-Means Clustering, K=3
clf = KMeans(n_clusters=3)
clf.fit(data)
print(clf.labels_)

plt.scatter(data[:, 0], data[:, 1], c=clf.labels_)
plt.show()
# Out:
# [1 2 0 1 0 1 0 2 1 0 1 2 1 1 0 2 1 0 2 2 0 1 2 1 0 2 2 2 1 2 1 1 1 2 1 1 1
#  0 0 2 2 0 1 2 2 2 1 0 0 0 2 1 0 1 1 2 1 0 1 2 1 2 2 0 2 0 1 1 2 1 1 0 1 2
#  2 1 2 0 1 2 1 1 1 2 2 1 2 0 1 1 2 1 1 0 1 2 1 1 1 2]
