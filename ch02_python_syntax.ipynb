# %% [markdown]
# # Python Environment for Data Science
# + **Notebook-style IDE** (編輯原始碼用)
#   + Google Colab
#   + VS Code with Jupyter extension
#   + Jupyter Lab
# + **直譯器** (轉原始碼成機器碼)
#   + Python 3
# + **運算資源** (實際執行程式的設備)
#   + 雲端
#   + 本機

# %% [markdown]
# # Basic Syntax: input, print, comment

# %%
# This is a comment
print("Hello, World!")  # print() outputs string, number to the console

name = input("Enter your name: ")  # get user input
print("Hello, " + name)
age = int(input("Enter your age: "))
print("You are", age, "years old.")

# %% [markdown]
# # Variable Naming Rules
# - Must start with an English letter, underscore _, or Chinese character
# - Can only contain English letters, digits, underscores, or Chinese characters.
# - Case sensitive: cat ≠ Cat
# - Cannot use reserved words (keywords)
# ```python
# 1. customer_list
# 2. print
# 3. True
# 4. Tesla Model Y
# 5. cat@
# 6. 4_tiger
# 7. part-id
# 9. _work
# 10. 客戶名稱
# ```

# %% [markdown]
# # Data Types

# %%
a = 5  # int
b = 3.14  # float
c = "Hello"  # str
d = True  # bool
e = [1, 2, 3] # list

print(type(a))

# %% [markdown]
# # Operators
# - Arithmetic operators: +, -, *, /, //, %, **
# - Order of arithmetic operations: (), **, -, (*, /, //, %), (+, -)
# - Comparison operators: ==, !=, >, <, >=, <=
# - Logical operators: and, or, not
# - Order of logical operators: not, and , or
# - Assignment operators: +=, -=, *=, /=, //=, %=, **=
# - String operators: +, *

# %% [markdown]
# # Lab
# 1. Assume a = 3, b = 4, write a program to calculate c
# $$
# a^{2} + b^{2} = c^{2}
# $$
#
# 2. According to user input of radius r, calculate the area of a circle
# $$
# Area = \pi r^{2}
# $$
# (Hint: use 3.14 for π)

# %% [markdown]
# # List: An Ordered and Mutable Container Type
# - A List is represented by elements separated with commas, enclosed in [ ].
# - The elements inside a List can be of different data types.

# %%
foo = [1, 'a', 9.9, False, [1,2]]
boo = []  # empty list
foo[0] = 100  # change the first element
print(foo[2]) # indexing
print(foo[-1])
print(foo[1:4]) # slicing
foo.append('HELLO')  # 加元素在最後
del foo[1]

grades = [['math', 45, 67, 23],
         ['english', 80, 70, 65],
         ['chinese', 90, 87, 95],
         ]
print(grades[1][0].capitalize(), '的第三個學生分數是', grades[1][3])

# %% [markdown]
# # Conditional Statements: if, elif, else

# %%
age = int(input("Enter your age: "))

if age < 18:
    print("You are a minor.")
elif age < 65:
    print("You are an adult.")
else:
    print("You are a senior citizen.")

# %% [markdown]
# # Lab
# Follow the flowchart to write a program that determines if a person's BMI is normal or not.
# ![Lab Image](https://dic.vbird.tw/javascript/unit04/4-1b.jpg)

# %% [markdown]
# # Looping Statements: for, while

# %%
fruits = ["apple", "banana", "cherry"]
for fruit in fruits:
    if fruit != "banana":
        print(fruit)

for i in range(5):  # 0,1,2,3,4
    print(i)

grades = [['Chinese', 'Math', 'English'],[80, 90, 85]]
for i in range(len(grades[0])):
    print(grades[0][i], '分數是', grades[1][i])    

num = 10; sum = 0; i = 1
while i <= num:
    sum = sum + i
    i = i + 1
print("Sum of first 10 number is:", sum)

# %% [markdown]
# # Modules

# %%
import math  # import the math module
from math import sqrt  # import specific functions from the math module
from math import pi as PI
print(math.sin(1.0))
print(sqrt(25))
print(PI)
